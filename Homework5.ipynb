# %% [markdown]
# # Case Intro
# Term deposits are a major source of income for a bank. A term deposit is a cash investment held at a financial institution. Your money is invested for an agreed rate of interest over a fixed amount of time, or term. The bank has various outreach plans to sell term deposits to their customers such as email marketing, advertisements, telephonic marketing, and digital marketing.
#
# Telephonic marketing campaigns still remain one of the most effective way to reach out to people. However, they require huge investment as large call centers are hired to actually execute these campaigns. Hence, it is crucial to identify the customers most likely to convert beforehand so that they can be specifically targeted via call.
#
# The data is related to direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe to a term deposit (variable y).
#
# Content
# The data is related to the direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed by the customer or not. The data folder contains two datasets:-
#
# Bank.csv: 45,211 rows and 18 columns ordered by date (from May 2008 to November 2010)
#
# Detailed Column Descriptions
# bank client data:
#
# 1 - age (numeric)
#
# 2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
# "blue-collar","self-employed","retired","technician","services")
#
# 3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#
# 4 - education (categorical: "unknown","secondary","primary","tertiary")
#
# 5 - default: has credit in default? (binary: "yes","no")
#
# 6 - balance: average yearly balance, in euros (numeric)
#
# 7 - housing: has housing loan? (binary: "yes","no")
#
# 8 - loan: has personal loan? (binary: "yes","no")
# # related with the last contact of the current campaign:
# 9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
# 10 - day: last contact day of the month (numeric)
#
# 11 - month: last contact month of year (categorical: "jan", "feb", "mar", …, "nov", "dec")
#
# 12 - duration: last contact duration, in seconds (numeric)
#
# # other attributes:
# 13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#
# 15 - previous: number of contacts performed before this campaign and for this client (numeric)
#
# 16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
# Output variable (desired target):
#
# 17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
# Missing Attribute Values: None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
print(df.shape)
df.info()
df.isnull().sum()
# Out:
# (45211, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv', sep=';')

# For object columns, check the value counts
for cn in df.columns:
    if df[cn].dtype == object:
        print(f"\nColumn: {cn}")
        print(df[cn].value_counts())
# Out:
# Column: job
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64
#
# Column: marital
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64
#
# Column: education
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64
#
# Column: default
# default
# no     44396
# yes      815
# Name: count, dtype: int64
#
# Column: housing
# housing
# yes    25130
# no     20081
# Name: count, dtype: int64
#
# Column: loan
# loan
# no     37967
# yes     7244
# Name: count, dtype: int64
#
# Column: contact
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64
#
# Column: month
# month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64
#
# Column: poutcome
# poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64
#
# Column: y
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
# Following function converts non-numeric variables (e.g., 'category', 'object') into numeric using label encoding
# Note:
#Label encoding converts categorical values into integer codes. Each unique category is assigned a distinct number, such as 1, 2, 3, 4, etc.
#Example : In our data, education variable has following values:{ 'primary' 'secondary', 'tertiary', 'unknown'}
#and it is mapped { 'primary': 0, 'secondary': 1, 'tertiary': 2, 'unknown': 3}

#  education  education_encoded
#  secondary                  1
#   tertiary                  2
#    primary                  0
#    unknown                  3
#   tertiary                  2
#    primary                  0
#
#Label encoding is generally suitable for tree-based models (e.g., decision trees, random forests, boosting methods).
#However, it may not be appropriate for models where the objective function relies on distance-based calculations, such as neural networks, support vector machines (SVM), or linear regression.
#For nominal features (categories with no intrinsic ordering, e.g., "red," "blue," "green"), label encoding can mislead the model by implying an ordinal relationship where none exists.
#In such cases, one-hot encoding is usually preferred.
#One-hot encoding creates binary columns (dummy variables) for each category in a categorical feature, avoiding the introduction of unintended ordinality.

import pandas as pd
from sklearn import preprocessing

url = 'https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv'
df = pd.read_csv(url, sep=';')

print("Shape:", df.shape)
print("\nInfo:")
print(df.info())
print("\nMissing values:")
print(df.isnull().sum())

print("\nUnique values in categorical columns:")
for col in df.columns:
    if df[col].dtype == 'object':
        print(f"\nColumn: {col}")
        print(df[col].value_counts())

def encode_label(df):
    columns_to_encode = df.select_dtypes(include=['object']).columns
    le = preprocessing.LabelEncoder()
    for col in columns_to_encode:
        df[col] = le.fit_transform(df[col])
    return df

df = encode_label(df)

print("\nEncoded DataFrame head:")
print(df.head())
# Out:
# Shape: (45211, 17)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# None
#
# Missing values:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64
#
# Unique values in categorical columns:
#
# Column: job
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64
#
# Column: marital
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64
#
# Column: education
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64
#
# Column: default
# default
# no     44396
# yes      815
# Name: count, dtype: int64
#
# Column: housing
# housing
# yes    25130
# no     20081
# Name: count, dtype: int64
#
# Column: loan
# loan
# no     37967
# yes     7244
# Name: count, dtype: int64
#
# Column: contact
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64
#
# Column: month
# month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64
#
# Column: poutcome
# poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64
#
# Column: y
# y
# no     39922
# yes     5289
# Name: count, dtype: int64
#
# Encoded DataFrame head:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8       261         1     -1         0         3  0
# 1    5      8       151         1     -1         0         3  0
# 2    5      8        76         1     -1         0         3  0
# 3    5      8        92         1     -1         0         3  0
# 4    5      8       198         1     -1         0         3  0

# %%
import pandas as pd
from sklearn import preprocessing

url = 'https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv'
df = pd.read_csv(url, sep=';')

print("Shape:", df.shape)
print("\nInfo:")
print(df.info())
print("\nMissing values:")
print(df.isnull().sum())

print("\nUnique values in categorical columns:")
for col in df.columns:
    if df[col].dtype == 'object':
        print(f"\nColumn: {col}")
        print(df[col].value_counts())

def Encoder(df):
    columns_to_encode = df.select_dtypes(include=['object']).columns
    le = preprocessing.LabelEncoder()
    for col in columns_to_encode:
        df[col] = le.fit_transform(df[col])
    return df

df = Encoder(df)

print("\nEncoded DataFrame head:")
print(df.head())

print("\nUnique values in encoded columns:")
for col in df.columns:
    if df[col].dtype == 'object':
        print(f"\nColumn: {col}")
        print(df[col].value_counts())
# Out:
# Shape: (45211, 17)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# None
#
# Missing values:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64
#
# Unique values in categorical columns:
#
# Column: job
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64
#
# Column: marital
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64
#
# Column: education
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64
#
# Column: default
# default
# no     44396
# yes      815
# Name: count, dtype: int64
#
# Column: housing
# housing
# yes    25130
# no     20081
# Name: count, dtype: int64
#
# Column: loan
# loan
# no     37967
# yes     7244
# Name: count, dtype: int64
#
# Column: contact
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64
#
# Column: month
# month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64
#
# Column: poutcome
# poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64
#
# Column: y
# y
# no     39922
# yes     5289
# Name: count, dtype: int64
#
# Encoded DataFrame head:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8       261         1     -1         0         3  0
# 1    5      8       151         1     -1         0         3  0
# 2    5      8        76         1     -1         0         3  0
# 3    5      8        92         1     -1         0         3  0
# 4    5      8       198         1     -1         0         3  0
#
# Unique values in encoded columns:

# %%
import pandas as pd
from sklearn import preprocessing

url = 'https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv'
df = pd.read_csv(url, sep=';')

print("Shape:", df.shape)
print("\nInfo:")
print(df.info())
print("\nMissing values:")
print(df.isnull().sum())

print("\nUnique values in categorical columns:")
for col in df.columns:
    if df[col].dtype == 'object':
        print(f"\nColumn: {col}")
        print(df[col].value_counts())

def Encoder(df):
    columns_to_encode = df.select_dtypes(include=['object']).columns
    le = preprocessing.LabelEncoder()
    for col in columns_to_encode:
        df[col] = le.fit_transform(df[col])
    return df

df = Encoder(df)

y = df['y']
X = df.drop('y', axis=1)
print("\nEncoded DataFrame (X):")
print(X.head())

print("\nUnique values in encoded columns:")
for col in X.columns:
    if X[col].dtype == 'object':
        print(f"\nColumn: {col}")
        print(X[col].value_counts())
# Out:
# Shape: (45211, 17)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# None
#
# Missing values:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64
#
# Unique values in categorical columns:
#
# Column: job
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64
#
# Column: marital
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64
#
# Column: education
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64
#
# Column: default
# default
# no     44396
# yes      815
# Name: count, dtype: int64
#
# Column: housing
# housing
# yes    25130
# no     20081
# Name: count, dtype: int64
#
# Column: loan
# loan
# no     37967
# yes     7244
# Name: count, dtype: int64
#
# Column: contact
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64
#
# Column: month
# month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64
#
# Column: poutcome
# poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64
#
# Column: y
# y
# no     39922
# yes     5289
# Name: count, dtype: int64
#
# Encoded DataFrame (X):
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome
# 0    5      8       261         1     -1         0         3
# 1    5      8       151         1     -1         0         3
# 2    5      8        76         1     -1         0         3
# 3    5      8        92         1     -1         0         3
# 4    5      8       198         1     -1         0         3
#
# Unique values in encoded columns:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

print("Size X_train:", X_train.shape)
print("Size X_test:", X_test.shape)
print("Size y_train:", y_train.shape)
print("Size y_test:", y_test.shape)
# Out:
# Size X_train: (33908, 16)
# Size X_test: (11303, 16)
# Size y_train: (33908,)
# Size y_test: (11303,)

# %% [markdown]
# Q1)Using  Random Forest,XGBoost, Light GBM and Gradient Boosting Classifier with default parameters (no parameter specifications except random_state) calculate Accuracy on Test data. Which method gives the best accuracy on test data

# %% [markdown]
# **To compare the accuracy of the models, we train Random Forest, XGBoost, LightGBM, and Gradient Boosting on the same data and evaluate them using accuracy on the test set. The model with the highest accuracy is considered the best.**

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

y = df['y']
X = df.drop('y', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

models = {
    "Random Forest": RandomForestClassifier(random_state=17),
    "XGBoost": XGBClassifier(random_state=17),
    "LightGBM": LGBMClassifier(random_state=17),
    "Gradient Boosting": GradientBoostingClassifier(random_state=17)
}

accuracy_results = {}
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy_results[model_name] = accuracy_score(y_test, y_pred)

for model_name, accuracy in accuracy_results.items():
    print(f"{model_name} Accuracy: {accuracy:.4f}")
# Out:
# [LightGBM] [Info] Number of positive: 3940, number of negative: 29968
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005168 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 33908, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116197 -> initscore=-2.028949
# [LightGBM] [Info] Start training from score -2.028949
# Random Forest Accuracy: 0.9025
# XGBoost Accuracy: 0.9037
# LightGBM Accuracy: 0.9074
# Gradient Boosting Accuracy: 0.9019

# %% [markdown]
# Q2) Using optuna hyperparmeter optimization technique and 100 trial
#
#  a)find best methods with  parameters  using Cross validation (CV=3) technique for the range of   parameters below. What are the best parameters for the method with highest cross validation accuracy?
#  For random forest
#
#
#   "max_depth"   : trial.suggest_int("max_depth", 2,  X_train.shape[1]),
#   "max_features": trial.suggest_int("max_features", 2, X_train.shape[1])
#
# For XGBoost, Light GBM and Gradient Boosting Classifier
#
#   "max_depth": trial.suggest_int("max_depth", 2, X_train.shape[1]),
#   "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3,log=True)
#
# where X_train.shape[1] is number of columnns in the train data.
#
#  b)Evaluate the performance of the  method with highest cross validation accuracy on test data.What is the accuracy value? Are there any improvement of the same method with default parameters?

# %% [markdown]
# **Optuna is used for hyperparameter optimization to find the best model and parameters that result in the highest cross-validation accuracy. After determining the best parameters, we evaluate the model's performance on the test data and compare it with the default model performance.**

# %%
# !pip install optuna
import optuna
import pandas as pd
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Load and preprocess data (assuming you have already done this in your notebook)
# ... (Your data loading and preprocessing code here) ...
# df = ...
# y = df['y']
# X = df.drop('y', axis=1)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

def objective_rf(trial):
  rf_params = {
      "max_depth": trial.suggest_int("max_depth", 2, X_train.shape[1]),
      "max_features": trial.suggest_int("max_features", 2, X_train.shape[1]),
      'random_state':17
  }
  model = RandomForestClassifier(**rf_params)
  score = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy').mean()
  return score

def objective_xgb(trial):
  xgb_params = {
      "max_depth": trial.suggest_int("max_depth", 2, X_train.shape[1]),
      "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3, log=True),
      'random_state':17
  }
  model = XGBClassifier(**xgb_params)
  score = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy').mean()
  return score

def objective_lgbm(trial):
  lgbm_params = {
      "max_depth": trial.suggest_int("max_depth", 2, X_train.shape[1]),
      "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3, log=True),
      'random_state':17
  }
  model = LGBMClassifier(**lgbm_params)
  score = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy').mean()
  return score

def objective_gb(trial):
  gb_params = {
      "max_depth": trial.suggest_int("max_depth", 2, X_train.shape[1]),
      "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3, log=True),
      'random_state':17
  }
  model = GradientBoostingClassifier(**gb_params)
  score = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy').mean()
  return score

# Create and optimize Optuna studies
study_rf = optuna.create_study(direction="maximize")
study_rf.optimize(objective_rf, n_trials=100)

study_xgb = optuna.create_study(direction="maximize")
study_xgb.optimize(objective_xgb, n_trials=100)

study_lgbm = optuna.create_study(direction="maximize")
study_lgbm.optimize(objective_lgbm, n_trials=100)

study_gb = optuna.create_study(direction="maximize")
study_gb.optimize(objective_gb, n_trials=100)

# Get best parameters and models
best_rf_params = study_rf.best_params
best_xgb_params = study_xgb.best_params
best_lgbm_params = study_lgbm.best_params
best_gb_params = study_gb.best_params

# Assuming Random Forest was the best
best_model = RandomForestClassifier(**best_rf_params)
best_model.fit(X_train, y_train)

# Predict and evaluate
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test data: {accuracy}")
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 19.0 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 15.5 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0
# [I 2025-04-15 06:24:06,636] A new study created in memory with name: no-name-d66401f7-7d60-4a10-b6ad-cbe3519c3afa
# [I 2025-04-15 06:24:10,708] Trial 0 finished with value: 0.8882269547160844 and parameters: {'max_depth': 3, 'max_features': 7}. Best is trial 0 with value: 0.8882269547160844.
# [I 2025-04-15 06:24:39,989] Trial 1 finished with value: 0.9024419031859862 and parameters: {'max_depth': 16, 'max_features': 14}. Best is trial 1 with value: 0.9024419031859862.
# [I 2025-04-15 06:24:42,635] Trial 2 finished with value: 0.8838032329432165 and parameters: {'max_depth': 2, 'max_features': 5}. Best is trial 1 with value: 0.9024419031859862.
# [I 2025-04-15 06:24:46,812] Trial 3 finished with value: 0.8955113939998224 and parameters: {'max_depth': 9, 'max_features': 2}. Best is trial 1 with value: 0.9024419031859862.
# [I 2025-04-15 06:25:05,034] Trial 4 finished with value: 0.9048897170359139 and parameters: {'max_depth': 9, 'max_features': 13}. Best is trial 4 with value: 0.9048897170359139.
# [I 2025-04-15 06:25:25,674] Trial 5 finished with value: 0.9041819116367847 and parameters: {'max_depth': 10, 'max_features': 14}. Best is trial 4 with value: 0.9048897170359139.
# [I 2025-04-15 06:25:28,518] Trial 6 finished with value: 0.8865164186956315 and parameters: {'max_depth': 5, 'max_features': 2}. Best is trial 4 with value: 0.9048897170359139.
# [I 2025-04-15 06:25:34,671] Trial 7 finished with value: 0.8926801828406433 and parameters: {'max_depth': 3, 'max_features': 11}. Best is trial 4 with value: 0.9048897170359139.
# [I 2025-04-15 06:25:42,283] Trial 8 finished with value: 0.9025009367640422 and parameters: {'max_depth': 6, 'max_features': 7}. Best is trial 4 with value: 0.9048897170359139.
# [I 2025-04-15 06:26:02,119] Trial 9 finished with value: 0.9049782204349813 and parameters: {'max_depth': 11, 'max_features': 12}. Best is trial 9 with value: 0.9049782204349813.
# [I 2025-04-15 06:26:33,757] Trial 10 finished with value: 0.9021175316267881 and parameters: {'max_depth': 14, 'max_features': 16}. Best is trial 9 with value: 0.9049782204349813.
# [I 2025-04-15 06:26:53,248] Trial 11 finished with value: 0.9049782204349813 and parameters: {'max_depth': 11, 'max_features': 12}. Best is trial 9 with value: 0.9049782204349813.
# [I 2025-04-15 06:27:11,742] Trial 12 finished with value: 0.9053320800805308 and parameters: {'max_depth': 12, 'max_features': 10}. Best is trial 12 with value: 0.9053320800805308.
# [I 2025-04-15 06:27:30,782] Trial 13 finished with value: 0.9047717960025198 and parameters: {'max_depth': 13, 'max_features': 10}. Best is trial 12 with value: 0.9053320800805308.
# [I 2025-04-15 06:27:45,599] Trial 14 finished with value: 0.9057745057491697 and parameters: {'max_depth': 12, 'max_features': 8}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:28:01,841] Trial 15 finished with value: 0.9047422948694973 and parameters: {'max_depth': 13, 'max_features': 8}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:28:13,756] Trial 16 finished with value: 0.9053321087832075 and parameters: {'max_depth': 16, 'max_features': 5}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:28:25,463] Trial 17 finished with value: 0.9053321087832075 and parameters: {'max_depth': 16, 'max_features': 5}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:28:36,880] Trial 18 finished with value: 0.9056269896467201 and parameters: {'max_depth': 15, 'max_features': 5}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:28:50,331] Trial 19 finished with value: 0.904093468252405 and parameters: {'max_depth': 14, 'max_features': 4}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:29:06,191] Trial 20 finished with value: 0.904771809049191 and parameters: {'max_depth': 8, 'max_features': 8}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:29:15,540] Trial 21 finished with value: 0.9045948413910697 and parameters: {'max_depth': 15, 'max_features': 4}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:29:29,106] Trial 22 finished with value: 0.904860286354916 and parameters: {'max_depth': 15, 'max_features': 6}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:29:37,686] Trial 23 finished with value: 0.9041229876507672 and parameters: {'max_depth': 16, 'max_features': 3}. Best is trial 14 with value: 0.9057745057491697.
# [I 2025-04-15 06:29:50,113] Trial 24 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:30:06,396] Trial 25 finished with value: 0.9048602576522393 and parameters: {'max_depth': 12, 'max_features': 9}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:30:21,119] Trial 26 finished with value: 0.9054795779176406 and parameters: {'max_depth': 13, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:30:34,093] Trial 27 finished with value: 0.9053911110492526 and parameters: {'max_depth': 14, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:30:49,938] Trial 28 finished with value: 0.9058334636565325 and parameters: {'max_depth': 11, 'max_features': 9}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:31:00,271] Trial 29 finished with value: 0.9046243399147581 and parameters: {'max_depth': 7, 'max_features': 9}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:31:13,301] Trial 30 finished with value: 0.9052731587038475 and parameters: {'max_depth': 10, 'max_features': 8}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:31:25,120] Trial 31 finished with value: 0.9057155347951357 and parameters: {'max_depth': 12, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:31:36,096] Trial 32 finished with value: 0.905302638962196 and parameters: {'max_depth': 11, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:31:49,550] Trial 33 finished with value: 0.9048897405199221 and parameters: {'max_depth': 12, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:32:03,561] Trial 34 finished with value: 0.9050077215680039 and parameters: {'max_depth': 10, 'max_features': 9}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:32:22,119] Trial 35 finished with value: 0.9053320800805308 and parameters: {'max_depth': 12, 'max_features': 10}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:32:32,745] Trial 36 finished with value: 0.904742292260163 and parameters: {'max_depth': 9, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:32:46,716] Trial 37 finished with value: 0.9050372044356866 and parameters: {'max_depth': 11, 'max_features': 8}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:32:53,308] Trial 38 finished with value: 0.9024124751143227 and parameters: {'max_depth': 8, 'max_features': 4}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:33:05,702] Trial 39 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:33:25,864] Trial 40 finished with value: 0.9052731378291735 and parameters: {'max_depth': 13, 'max_features': 11}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:33:37,667] Trial 41 finished with value: 0.9057155347951357 and parameters: {'max_depth': 12, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:33:52,261] Trial 42 finished with value: 0.9050961623430495 and parameters: {'max_depth': 14, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:34:03,349] Trial 43 finished with value: 0.905302638962196 and parameters: {'max_depth': 11, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:34:09,966] Trial 44 finished with value: 0.9011443151851579 and parameters: {'max_depth': 10, 'max_features': 3}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:34:25,492] Trial 45 finished with value: 0.9047422948694973 and parameters: {'max_depth': 13, 'max_features': 8}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:34:29,251] Trial 46 finished with value: 0.8842456038158361 and parameters: {'max_depth': 2, 'max_features': 10}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:34:52,865] Trial 47 finished with value: 0.903680580247468 and parameters: {'max_depth': 10, 'max_features': 16}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:35:11,617] Trial 48 finished with value: 0.9048307043325319 and parameters: {'max_depth': 11, 'max_features': 11}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:35:21,570] Trial 49 finished with value: 0.905862985664229 and parameters: {'max_depth': 12, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:35:29,394] Trial 50 finished with value: 0.903326681461905 and parameters: {'max_depth': 14, 'max_features': 3}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:35:39,763] Trial 51 finished with value: 0.905862985664229 and parameters: {'max_depth': 12, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:35:50,680] Trial 52 finished with value: 0.9056565534037645 and parameters: {'max_depth': 13, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:36:01,061] Trial 53 finished with value: 0.905862985664229 and parameters: {'max_depth': 12, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:36:08,708] Trial 54 finished with value: 0.9046538071264353 and parameters: {'max_depth': 11, 'max_features': 4}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:36:15,168] Trial 55 finished with value: 0.9003775127386523 and parameters: {'max_depth': 13, 'max_features': 2}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:36:42,798] Trial 56 finished with value: 0.9027958489395657 and parameters: {'max_depth': 15, 'max_features': 14}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:36:54,165] Trial 57 finished with value: 0.905538574965017 and parameters: {'max_depth': 14, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:37:04,582] Trial 58 finished with value: 0.905862985664229 and parameters: {'max_depth': 12, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:37:15,324] Trial 59 finished with value: 0.9056565534037645 and parameters: {'max_depth': 13, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:37:18,932] Trial 60 finished with value: 0.8900554326446053 and parameters: {'max_depth': 4, 'max_features': 4}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:37:29,338] Trial 61 finished with value: 0.905862985664229 and parameters: {'max_depth': 12, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:37:39,151] Trial 62 finished with value: 0.905862985664229 and parameters: {'max_depth': 12, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:37:46,462] Trial 63 finished with value: 0.9024714330216854 and parameters: {'max_depth': 12, 'max_features': 3}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:37:55,830] Trial 64 finished with value: 0.9052141277351257 and parameters: {'max_depth': 13, 'max_features': 4}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:38:07,556] Trial 65 finished with value: 0.9056269896467201 and parameters: {'max_depth': 15, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:38:19,520] Trial 66 finished with value: 0.9057155347951357 and parameters: {'max_depth': 12, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:38:25,382] Trial 67 finished with value: 0.9015571353474043 and parameters: {'max_depth': 14, 'max_features': 2}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:38:34,735] Trial 68 finished with value: 0.9052141277351257 and parameters: {'max_depth': 13, 'max_features': 4}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:38:48,050] Trial 69 finished with value: 0.9048897405199221 and parameters: {'max_depth': 12, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:39:08,631] Trial 70 finished with value: 0.9048307225978715 and parameters: {'max_depth': 9, 'max_features': 15}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:39:18,250] Trial 71 finished with value: 0.9048012840888711 and parameters: {'max_depth': 10, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:39:27,948] Trial 72 finished with value: 0.9054205756515955 and parameters: {'max_depth': 11, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:39:37,645] Trial 73 finished with value: 0.9054205756515955 and parameters: {'max_depth': 11, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:39:46,631] Trial 74 finished with value: 0.9043883882559314 and parameters: {'max_depth': 12, 'max_features': 4}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:39:58,956] Trial 75 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:40:12,093] Trial 76 finished with value: 0.9053911110492526 and parameters: {'max_depth': 14, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:40:23,918] Trial 77 finished with value: 0.9057155347951357 and parameters: {'max_depth': 12, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:40:38,256] Trial 78 finished with value: 0.9054795779176406 and parameters: {'max_depth': 13, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:40:45,475] Trial 79 finished with value: 0.903533142425046 and parameters: {'max_depth': 13, 'max_features': 3}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:40:58,942] Trial 80 finished with value: 0.904860286354916 and parameters: {'max_depth': 15, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:41:09,369] Trial 81 finished with value: 0.905862985664229 and parameters: {'max_depth': 12, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:41:19,140] Trial 82 finished with value: 0.9054205756515955 and parameters: {'max_depth': 11, 'max_features': 5}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:41:28,041] Trial 83 finished with value: 0.9043883882559314 and parameters: {'max_depth': 12, 'max_features': 4}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:41:40,499] Trial 84 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:41:55,092] Trial 85 finished with value: 0.9050961623430495 and parameters: {'max_depth': 14, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:42:07,520] Trial 86 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:42:19,982] Trial 87 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:42:34,014] Trial 88 finished with value: 0.9054795779176406 and parameters: {'max_depth': 13, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:42:50,285] Trial 89 finished with value: 0.9053026572275357 and parameters: {'max_depth': 14, 'max_features': 8}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:43:02,725] Trial 90 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:43:15,211] Trial 91 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:43:27,693] Trial 92 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:43:40,709] Trial 93 finished with value: 0.9053911110492526 and parameters: {'max_depth': 14, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:43:53,156] Trial 94 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:44:07,247] Trial 95 finished with value: 0.9054795779176406 and parameters: {'max_depth': 13, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:44:21,699] Trial 96 finished with value: 0.9054795779176406 and parameters: {'max_depth': 13, 'max_features': 7}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:44:34,852] Trial 97 finished with value: 0.9053911110492526 and parameters: {'max_depth': 14, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:44:47,269] Trial 98 finished with value: 0.9060989060110446 and parameters: {'max_depth': 13, 'max_features': 6}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:45:04,750] Trial 99 finished with value: 0.9048897379105879 and parameters: {'max_depth': 16, 'max_features': 8}. Best is trial 24 with value: 0.9060989060110446.
# [I 2025-04-15 06:45:04,751] A new study created in memory with name: no-name-5d1ada26-11d0-42e7-819a-202f90550c59
# [I 2025-04-15 06:45:09,341] Trial 0 finished with value: 0.8838032329432165 and parameters: {'max_depth': 15, 'learning_rate': 0.001418602148161941}. Best is trial 0 with value: 0.8838032329432165.
# [I 2025-04-15 06:45:10,007] Trial 1 finished with value: 0.9052141799218107 and parameters: {'max_depth': 3, 'learning_rate': 0.11148082500510755}. Best is trial 1 with value: 0.9052141799218107.
# [I 2025-04-15 06:45:15,902] Trial 2 finished with value: 0.9026188630161047 and parameters: {'max_depth': 13, 'learning_rate': 0.04098930647405818}. Best is trial 1 with value: 0.9052141799218107.
# [I 2025-04-15 06:45:17,438] Trial 3 finished with value: 0.8966616094115847 and parameters: {'max_depth': 7, 'learning_rate': 0.01304673373290701}. Best is trial 1 with value: 0.9052141799218107.
# [I 2025-04-15 06:45:18,660] Trial 4 finished with value: 0.8856316978250661 and parameters: {'max_depth': 6, 'learning_rate': 0.007869083641435343}. Best is trial 1 with value: 0.9052141799218107.
# [I 2025-04-15 06:45:19,867] Trial 5 finished with value: 0.9037690497251903 and parameters: {'max_depth': 6, 'learning_rate': 0.03297030994029189}. Best is trial 1 with value: 0.9052141799218107.
# [I 2025-04-15 06:45:21,848] Trial 6 finished with value: 0.905391105830584 and parameters: {'max_depth': 9, 'learning_rate': 0.0795552372344078}. Best is trial 6 with value: 0.905391105830584.
# [I 2025-04-15 06:45:23,334] Trial 7 finished with value: 0.8838032329432165 and parameters: {'max_depth': 7, 'learning_rate': 0.0022576900646619296}. Best is trial 6 with value: 0.905391105830584.
# [I 2025-04-15 06:45:25,413] Trial 8 finished with value: 0.8838032329432165 and parameters: {'max_depth': 3, 'learning_rate': 0.00867661301673294}. Best is trial 6 with value: 0.905391105830584.
# [I 2025-04-15 06:45:27,315] Trial 9 finished with value: 0.901291742570243 and parameters: {'max_depth': 7, 'learning_rate': 0.019751269581036998}. Best is trial 6 with value: 0.905391105830584.
# [I 2025-04-15 06:45:29,594] Trial 10 finished with value: 0.903385652415939 and parameters: {'max_depth': 11, 'learning_rate': 0.19410103729856912}. Best is trial 6 with value: 0.905391105830584.
# [I 2025-04-15 06:45:30,384] Trial 11 finished with value: 0.9078389275085144 and parameters: {'max_depth': 4, 'learning_rate': 0.16911614450151205}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:32,655] Trial 12 finished with value: 0.904948742785967 and parameters: {'max_depth': 10, 'learning_rate': 0.09288970002506794}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:33,249] Trial 13 finished with value: 0.9048013519315615 and parameters: {'max_depth': 2, 'learning_rate': 0.24277682770022935}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:39,581] Trial 14 finished with value: 0.9035035786680016 and parameters: {'max_depth': 16, 'learning_rate': 0.06614912614982207}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:41,971] Trial 15 finished with value: 0.9025893853670904 and parameters: {'max_depth': 12, 'learning_rate': 0.292746148274906}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:43,827] Trial 16 finished with value: 0.9047128250484858 and parameters: {'max_depth': 9, 'learning_rate': 0.1379284522242007}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:44,806] Trial 17 finished with value: 0.9062758580131604 and parameters: {'max_depth': 5, 'learning_rate': 0.06168298264115391}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:45,636] Trial 18 finished with value: 0.9035921655657652 and parameters: {'max_depth': 4, 'learning_rate': 0.04079655094601267}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:46,646] Trial 19 finished with value: 0.901291805194265 and parameters: {'max_depth': 5, 'learning_rate': 0.023805583546010374}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:47,210] Trial 20 finished with value: 0.8838032329432165 and parameters: {'max_depth': 2, 'learning_rate': 0.0044237907613713144}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:51,063] Trial 21 finished with value: 0.9046243059934128 and parameters: {'max_depth': 9, 'learning_rate': 0.07205184216101965}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:51,992] Trial 22 finished with value: 0.9071900878447509 and parameters: {'max_depth': 5, 'learning_rate': 0.15208344837529905}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:52,776] Trial 23 finished with value: 0.906688732971426 and parameters: {'max_depth': 4, 'learning_rate': 0.16589819021267416}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:53,535] Trial 24 finished with value: 0.9073965644638974 and parameters: {'max_depth': 4, 'learning_rate': 0.16429413901417755}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:54,337] Trial 25 finished with value: 0.9068066905354994 and parameters: {'max_depth': 4, 'learning_rate': 0.13147556354863454}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:55,239] Trial 26 finished with value: 0.9059809249629627 and parameters: {'max_depth': 5, 'learning_rate': 0.20162324478490465}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:55,911] Trial 27 finished with value: 0.9065413395076861 and parameters: {'max_depth': 3, 'learning_rate': 0.2675547854877561}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:57,674] Trial 28 finished with value: 0.9051846370394402 and parameters: {'max_depth': 8, 'learning_rate': 0.04675615302685035}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:58,782] Trial 29 finished with value: 0.9058334740938694 and parameters: {'max_depth': 6, 'learning_rate': 0.11505716947377671}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:45:59,347] Trial 30 finished with value: 0.8838032329432165 and parameters: {'max_depth': 2, 'learning_rate': 0.001626185737616688}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:00,153] Trial 31 finished with value: 0.9062463960201516 and parameters: {'max_depth': 4, 'learning_rate': 0.13814437321865997}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:00,971] Trial 32 finished with value: 0.9060694309713645 and parameters: {'max_depth': 4, 'learning_rate': 0.11578092763149721}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:03,360] Trial 33 finished with value: 0.9051552272331165 and parameters: {'max_depth': 3, 'learning_rate': 0.14674570406700113}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:04,294] Trial 34 finished with value: 0.9070131332333009 and parameters: {'max_depth': 5, 'learning_rate': 0.18166214749109622}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:07,235] Trial 35 finished with value: 0.9030907271937442 and parameters: {'max_depth': 14, 'learning_rate': 0.1991122748714531}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:08,407] Trial 36 finished with value: 0.905509047738652 and parameters: {'max_depth': 6, 'learning_rate': 0.08821534153630574}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:09,831] Trial 37 finished with value: 0.9051551385157519 and parameters: {'max_depth': 7, 'learning_rate': 0.0549414295962197}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:10,873] Trial 38 finished with value: 0.9036216353867766 and parameters: {'max_depth': 5, 'learning_rate': 0.034284965754986}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:11,943] Trial 39 finished with value: 0.9044473800846394 and parameters: {'max_depth': 6, 'learning_rate': 0.29466315663958853}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:15,534] Trial 40 finished with value: 0.8987850151716348 and parameters: {'max_depth': 8, 'learning_rate': 0.014065120343029501}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:16,565] Trial 41 finished with value: 0.9070426291476549 and parameters: {'max_depth': 4, 'learning_rate': 0.11178594277492712}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:17,245] Trial 42 finished with value: 0.9043589106069172 and parameters: {'max_depth': 3, 'learning_rate': 0.09656875974492753}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:18,163] Trial 43 finished with value: 0.9067772076678168 and parameters: {'max_depth': 5, 'learning_rate': 0.20741874106130243}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:18,849] Trial 44 finished with value: 0.9029433232926674 and parameters: {'max_depth': 2, 'learning_rate': 0.16216374557200142}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:19,539] Trial 45 finished with value: 0.9040640193060675 and parameters: {'max_depth': 3, 'learning_rate': 0.09858666422494818}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:20,610] Trial 46 finished with value: 0.9052731560945132 and parameters: {'max_depth': 6, 'learning_rate': 0.2255346694569639}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:22,019] Trial 47 finished with value: 0.9061873754887668 and parameters: {'max_depth': 7, 'learning_rate': 0.07704431026372117}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:22,884] Trial 48 finished with value: 0.9004365515353768 and parameters: {'max_depth': 4, 'learning_rate': 0.026510512999906994}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:24,835] Trial 49 finished with value: 0.8838032329432165 and parameters: {'max_depth': 8, 'learning_rate': 0.0032503311916774595}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:25,756] Trial 50 finished with value: 0.9062168609657838 and parameters: {'max_depth': 5, 'learning_rate': 0.16405495924956892}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:28,364] Trial 51 finished with value: 0.9071016235856971 and parameters: {'max_depth': 4, 'learning_rate': 0.12215571281228924}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:29,060] Trial 52 finished with value: 0.9046538280011092 and parameters: {'max_depth': 3, 'learning_rate': 0.10165054734473003}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:29,833] Trial 53 finished with value: 0.9070426448036604 and parameters: {'max_depth': 4, 'learning_rate': 0.17684917773172945}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:30,629] Trial 54 finished with value: 0.907543997067651 and parameters: {'max_depth': 4, 'learning_rate': 0.12191270124211766}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:31,312] Trial 55 finished with value: 0.9067772076678168 and parameters: {'max_depth': 3, 'learning_rate': 0.2570119380374214}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:31,890] Trial 56 finished with value: 0.895275507574352 and parameters: {'max_depth': 2, 'learning_rate': 0.057244962119183514}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:32,691] Trial 57 finished with value: 0.9070426265383206 and parameters: {'max_depth': 4, 'learning_rate': 0.13202742890170788}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:33,666] Trial 58 finished with value: 0.9066887225340889 and parameters: {'max_depth': 5, 'learning_rate': 0.08119246730269433}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:37,662] Trial 59 finished with value: 0.8842750814648505 and parameters: {'max_depth': 12, 'learning_rate': 0.006384369450256413}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:38,280] Trial 60 finished with value: 0.9048602889642502 and parameters: {'max_depth': 2, 'learning_rate': 0.2341124573326744}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:40,743] Trial 61 finished with value: 0.9074555275899288 and parameters: {'max_depth': 4, 'learning_rate': 0.11923843092077538}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:41,662] Trial 62 finished with value: 0.9068656823642076 and parameters: {'max_depth': 4, 'learning_rate': 0.1772900991277298}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:42,367] Trial 63 finished with value: 0.9053026546182016 and parameters: {'max_depth': 3, 'learning_rate': 0.12857173700730257}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:44,780] Trial 64 finished with value: 0.9045063849600187 and parameters: {'max_depth': 10, 'learning_rate': 0.0652630121104201}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:45,579] Trial 65 finished with value: 0.9066592553224117 and parameters: {'max_depth': 4, 'learning_rate': 0.15470001483942525}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:46,519] Trial 66 finished with value: 0.8838032329432165 and parameters: {'max_depth': 5, 'learning_rate': 0.0010348558891765706}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:47,633] Trial 67 finished with value: 0.9058630039295688 and parameters: {'max_depth': 6, 'learning_rate': 0.12209851253778187}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:48,403] Trial 68 finished with value: 0.9074260316755747 and parameters: {'max_depth': 4, 'learning_rate': 0.22707564676656702}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:49,312] Trial 69 finished with value: 0.9062463281774611 and parameters: {'max_depth': 5, 'learning_rate': 0.23565113725962883}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:50,032] Trial 70 finished with value: 0.9004365202233658 and parameters: {'max_depth': 3, 'learning_rate': 0.04764417207381008}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:50,810] Trial 71 finished with value: 0.9068951495758849 and parameters: {'max_depth': 4, 'learning_rate': 0.29965301552969614}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:53,020] Trial 72 finished with value: 0.9055680995820478 and parameters: {'max_depth': 3, 'learning_rate': 0.19078327744577636}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:54,104] Trial 73 finished with value: 0.9077504710774633 and parameters: {'max_depth': 4, 'learning_rate': 0.1453609981410324}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:55,223] Trial 74 finished with value: 0.9054205834795983 and parameters: {'max_depth': 6, 'learning_rate': 0.14473996337214068}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:59,081] Trial 75 finished with value: 0.9028253500725884 and parameters: {'max_depth': 16, 'learning_rate': 0.10742387554107456}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:46:59,881] Trial 76 finished with value: 0.9056860258341103 and parameters: {'max_depth': 4, 'learning_rate': 0.0801525236615122}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:47:00,474] Trial 77 finished with value: 0.9048897874879387 and parameters: {'max_depth': 2, 'learning_rate': 0.21434150304997104}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:47:01,442] Trial 78 finished with value: 0.9057744431251477 and parameters: {'max_depth': 5, 'learning_rate': 0.08849252312290677}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:47:02,137] Trial 79 finished with value: 0.9062759154185138 and parameters: {'max_depth': 3, 'learning_rate': 0.14560501193086975}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:47:03,138] Trial 80 finished with value: 0.9059514081739347 and parameters: {'max_depth': 5, 'learning_rate': 0.07074081075960252}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:47:05,425] Trial 81 finished with value: 0.9070426448036604 and parameters: {'max_depth': 4, 'learning_rate': 0.17686659089710913}. Best is trial 11 with value: 0.9078389275085144.
# [I 2025-04-15 06:47:06,530] Trial 82 finished with value: 0.9079568798539194 and parameters: {'max_depth': 4, 'learning_rate': 0.2484344566209514}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:07,307] Trial 83 finished with value: 0.9058629178215384 and parameters: {'max_depth': 4, 'learning_rate': 0.25677434822450734}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:07,984] Trial 84 finished with value: 0.9050372461850347 and parameters: {'max_depth': 3, 'learning_rate': 0.11725356182441286}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:08,899] Trial 85 finished with value: 0.905685991912765 and parameters: {'max_depth': 5, 'learning_rate': 0.21369864352234952}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:09,966] Trial 86 finished with value: 0.904830769565888 and parameters: {'max_depth': 6, 'learning_rate': 0.27073179954907844}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:10,794] Trial 87 finished with value: 0.9072785990718212 and parameters: {'max_depth': 4, 'learning_rate': 0.14609580059024999}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:11,725] Trial 88 finished with value: 0.9065117809693102 and parameters: {'max_depth': 5, 'learning_rate': 0.15309403844219632}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:12,412] Trial 89 finished with value: 0.9057155426231384 and parameters: {'max_depth': 3, 'learning_rate': 0.19109998522454877}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:13,206] Trial 90 finished with value: 0.9062168766217894 and parameters: {'max_depth': 4, 'learning_rate': 0.10145483752937172}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:14,004] Trial 91 finished with value: 0.907190090454085 and parameters: {'max_depth': 4, 'learning_rate': 0.14014520684294945}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:14,800] Trial 92 finished with value: 0.9066003000243832 and parameters: {'max_depth': 4, 'learning_rate': 0.13770825029665978}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:15,473] Trial 93 finished with value: 0.9060104313146536 and parameters: {'max_depth': 3, 'learning_rate': 0.21789424115253542}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:17,619] Trial 94 finished with value: 0.9075144698412861 and parameters: {'max_depth': 5, 'learning_rate': 0.16733761323817722}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:21,125] Trial 95 finished with value: 0.9038871090532997 and parameters: {'max_depth': 15, 'learning_rate': 0.2469258055171707}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:21,906] Trial 96 finished with value: 0.9077799591638147 and parameters: {'max_depth': 4, 'learning_rate': 0.16740407340616292}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:22,484] Trial 97 finished with value: 0.9036511391291334 and parameters: {'max_depth': 2, 'learning_rate': 0.16197349177098064}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:23,774] Trial 98 finished with value: 0.9052142086244874 and parameters: {'max_depth': 7, 'learning_rate': 0.19785813047739198}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:24,745] Trial 99 finished with value: 0.8845994921640622 and parameters: {'max_depth': 5, 'learning_rate': 0.00904710225481338}. Best is trial 82 with value: 0.9079568798539194.
# [I 2025-04-15 06:47:24,750] A new study created in memory with name: no-name-1e9df515-aa12-4bb7-9724-95676f46ba32
# [LightGBM] [Info] Number of positive: 2627, number of negative: 19978
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002862 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 978
# [LightGBM] [Info] Number of data points in the train set: 22605, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116213 -> initscore=-2.028789
# [LightGBM] [Info] Start training from score -2.028789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2626, number of negative: 19979
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002730 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...
# [I 2025-04-15 07:07:42,774] Trial 20 finished with value: 0.8963667102827323 and parameters: {'max_depth': 8, 'learning_rate': 0.011068520800865058}. Best is trial 16 with value: 0.9029432371846372.
# [I 2025-04-15 07:08:14,813] Trial 21 finished with value: 0.9022354709255218 and parameters: {'max_depth': 8, 'learning_rate': 0.02991547316354463}. Best is trial 16 with value: 0.9029432371846372.
# [I 2025-04-15 07:08:41,961] Trial 22 finished with value: 0.9036510765051115 and parameters: {'max_depth': 7, 'learning_rate': 0.02741054564562223}. Best is trial 22 with value: 0.9036510765051115.
# [I 2025-04-15 07:09:09,833] Trial 23 finished with value: 0.9019405822340065 and parameters: {'max_depth': 7, 'learning_rate': 0.02027147003882921}. Best is trial 22 with value: 0.9036510765051115.
# [I 2025-04-15 07:09:54,738] Trial 24 finished with value: 0.9014981983147156 and parameters: {'max_depth': 10, 'learning_rate': 0.04757304962518134}. Best is trial 22 with value: 0.9036510765051115.
# [I 2025-04-15 07:10:21,816] Trial 25 finished with value: 0.9005840024044702 and parameters: {'max_depth': 7, 'learning_rate': 0.015839983048937058}. Best is trial 22 with value: 0.9036510765051115.
# [I 2025-04-15 07:10:33,266] Trial 26 finished with value: 0.8838032329432165 and parameters: {'max_depth': 3, 'learning_rate': 0.008269398033301817}. Best is trial 22 with value: 0.9036510765051115.
# [I 2025-04-15 07:11:11,939] Trial 27 finished with value: 0.9021765156274933 and parameters: {'max_depth': 9, 'learning_rate': 0.04604478398787978}. Best is trial 22 with value: 0.9036510765051115.
# [I 2025-04-15 07:11:34,791] Trial 28 finished with value: 0.9050961597337152 and parameters: {'max_depth': 6, 'learning_rate': 0.13117361155585455}. Best is trial 28 with value: 0.9050961597337152.
# [I 2025-04-15 07:11:57,641] Trial 29 finished with value: 0.9060398672143201 and parameters: {'max_depth': 6, 'learning_rate': 0.11067341828944885}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:12:05,595] Trial 30 finished with value: 0.9029138508623217 and parameters: {'max_depth': 2, 'learning_rate': 0.12938967839132084}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:12:27,634] Trial 31 finished with value: 0.9055974806856947 and parameters: {'max_depth': 6, 'learning_rate': 0.11525868418449034}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:12:50,181] Trial 32 finished with value: 0.9053616046975614 and parameters: {'max_depth': 6, 'learning_rate': 0.12298126928251123}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:13:12,688] Trial 33 finished with value: 0.9059809354002998 and parameters: {'max_depth': 6, 'learning_rate': 0.11767268011404204}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:13:27,261] Trial 34 finished with value: 0.9059809510563053 and parameters: {'max_depth': 4, 'learning_rate': 0.172276730880452}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:13:41,912] Trial 35 finished with value: 0.9046833239154632 and parameters: {'max_depth': 4, 'learning_rate': 0.0954414179249756}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:13:53,185] Trial 36 finished with value: 0.9050372618410402 and parameters: {'max_depth': 3, 'learning_rate': 0.17979515761695494}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:14:07,928] Trial 37 finished with value: 0.903621627558774 and parameters: {'max_depth': 4, 'learning_rate': 0.05563380563184735}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:14:16,029] Trial 38 finished with value: 0.9037101205205044 and parameters: {'max_depth': 2, 'learning_rate': 0.16450956398762642}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:14:34,072] Trial 39 finished with value: 0.9052141042511175 and parameters: {'max_depth': 5, 'learning_rate': 0.09925350954855311}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:14:45,270] Trial 40 finished with value: 0.9050962354044083 and parameters: {'max_depth': 3, 'learning_rate': 0.2987727176707808}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:15:07,686] Trial 41 finished with value: 0.904860150669535 and parameters: {'max_depth': 6, 'learning_rate': 0.12043052629905841}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:15:25,996] Trial 42 finished with value: 0.9048012945262082 and parameters: {'max_depth': 5, 'learning_rate': 0.17830272957502233}. Best is trial 29 with value: 0.9060398672143201.
# [I 2025-04-15 07:15:48,462] Trial 43 finished with value: 0.9062463073027871 and parameters: {'max_depth': 6, 'learning_rate': 0.06115643519497851}. Best is trial 43 with value: 0.9062463073027871.
# [I 2025-04-15 07:16:03,431] Trial 44 finished with value: 0.9041819586048013 and parameters: {'max_depth': 4, 'learning_rate': 0.0603347108542452}. Best is trial 43 with value: 0.9062463073027871.
# [I 2025-04-15 07:16:25,729] Trial 45 finished with value: 0.9051551750464314 and parameters: {'max_depth': 6, 'learning_rate': 0.1008070924127901}. Best is trial 43 with value: 0.9062463073027871.
# [I 2025-04-15 07:16:51,854] Trial 46 finished with value: 0.902500913280034 and parameters: {'max_depth': 7, 'learning_rate': 0.21483326735804636}. Best is trial 43 with value: 0.9062463073027871.
# [I 2025-04-15 07:17:10,750] Trial 47 finished with value: 0.9055385253876663 and parameters: {'max_depth': 5, 'learning_rate': 0.07324063026886458}. Best is trial 43 with value: 0.9062463073027871.
# [I 2025-04-15 07:17:25,273] Trial 48 finished with value: 0.8838032329432165 and parameters: {'max_depth': 4, 'learning_rate': 0.0014578487697704421}. Best is trial 43 with value: 0.9062463073027871.
# [I 2025-04-15 07:17:43,268] Trial 49 finished with value: 0.9056565455757619 and parameters: {'max_depth': 5, 'learning_rate': 0.14838820746957265}. Best is trial 43 with value: 0.9062463073027871.
# [I 2025-04-15 07:18:19,942] Trial 50 finished with value: 0.9007609074385695 and parameters: {'max_depth': 9, 'learning_rate': 0.23888573163371474}. Best is trial 43 with value: 0.9062463073027871.
# [I 2025-04-15 07:18:38,735] Trial 51 finished with value: 0.9064822981016274 and parameters: {'max_depth': 5, 'learning_rate': 0.15356808278381964}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:18:56,696] Trial 52 finished with value: 0.9059219513995944 and parameters: {'max_depth': 5, 'learning_rate': 0.1443127544537172}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:19:15,332] Trial 53 finished with value: 0.9054206304476148 and parameters: {'max_depth': 5, 'learning_rate': 0.19603284758105552}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:19:26,510] Trial 54 finished with value: 0.9032972299062333 and parameters: {'max_depth': 3, 'learning_rate': 0.08826614215789536}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:19:41,106] Trial 55 finished with value: 0.9049192651369529 and parameters: {'max_depth': 4, 'learning_rate': 0.15146327221391523}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:20:07,299] Trial 56 finished with value: 0.9005544986621135 and parameters: {'max_depth': 7, 'learning_rate': 0.24141326204369654}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:20:29,944] Trial 57 finished with value: 0.8838032329432165 and parameters: {'max_depth': 6, 'learning_rate': 0.003500051132394677}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:20:48,099] Trial 58 finished with value: 0.9059514368766114 and parameters: {'max_depth': 5, 'learning_rate': 0.062144466797967264}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:21:14,640] Trial 59 finished with value: 0.9043293442405383 and parameters: {'max_depth': 7, 'learning_rate': 0.061525573482620485}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:21:25,955] Trial 60 finished with value: 0.9018226455446069 and parameters: {'max_depth': 3, 'learning_rate': 0.0428225316504565}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:21:40,558] Trial 61 finished with value: 0.9050667029593749 and parameters: {'max_depth': 4, 'learning_rate': 0.078635213975517}. Best is trial 51 with value: 0.9064822981016274.
# [I 2025-04-15 07:21:59,326] Trial 62 finished with value: 0.9067772024491482 and parameters: {'max_depth': 5, 'learning_rate': 0.10557454184874485}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:22:21,141] Trial 63 finished with value: 0.9053321244392128 and parameters: {'max_depth': 6, 'learning_rate': 0.10317060661141067}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:22:39,609] Trial 64 finished with value: 0.9056269896467201 and parameters: {'max_depth': 5, 'learning_rate': 0.07130897302949618}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:22:54,258] Trial 65 finished with value: 0.9021470431971474 and parameters: {'max_depth': 4, 'learning_rate': 0.024312040045708205}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:23:21,014] Trial 66 finished with value: 0.9031497164131178 and parameters: {'max_depth': 7, 'learning_rate': 0.04121425761414225}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:23:58,226] Trial 67 finished with value: 0.9027368205801783 and parameters: {'max_depth': 9, 'learning_rate': 0.05919406770862714}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:24:49,550] Trial 68 finished with value: 0.9013507396176195 and parameters: {'max_depth': 11, 'learning_rate': 0.0893967363959287}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:24:57,562] Trial 69 finished with value: 0.9019111437250059 and parameters: {'max_depth': 2, 'learning_rate': 0.11583503915045194}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:25:20,241] Trial 70 finished with value: 0.9046537810330927 and parameters: {'max_depth': 6, 'learning_rate': 0.03768528762969001}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:25:38,152] Trial 71 finished with value: 0.9052731352198392 and parameters: {'max_depth': 5, 'learning_rate': 0.1459485742783232}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:25:56,830] Trial 72 finished with value: 0.9058629282588755 and parameters: {'max_depth': 5, 'learning_rate': 0.18900545925705264}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:26:14,874] Trial 73 finished with value: 0.9065117522666334 and parameters: {'max_depth': 5, 'learning_rate': 0.13750762842548828}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:26:29,368] Trial 74 finished with value: 0.9055680291300231 and parameters: {'max_depth': 4, 'learning_rate': 0.2739714380899086}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:28:14,833] Trial 75 finished with value: 0.8962192411482994 and parameters: {'max_depth': 15, 'learning_rate': 0.05227233488330304}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:28:36,971] Trial 76 finished with value: 0.9060104000026428 and parameters: {'max_depth': 6, 'learning_rate': 0.10849635407869176}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:28:59,691] Trial 77 finished with value: 0.9054500741752838 and parameters: {'max_depth': 6, 'learning_rate': 0.11112155957762511}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:29:26,139] Trial 78 finished with value: 0.9021469779637913 and parameters: {'max_depth': 7, 'learning_rate': 0.16696053960589063}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:29:48,758] Trial 79 finished with value: 0.9035625861527151 and parameters: {'max_depth': 6, 'learning_rate': 0.12943238818334662}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:30:21,099] Trial 80 finished with value: 0.903562596590052 and parameters: {'max_depth': 8, 'learning_rate': 0.08468916914500853}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:30:39,457] Trial 81 finished with value: 0.90559751460704 and parameters: {'max_depth': 5, 'learning_rate': 0.06653839163453312}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:31:02,207] Trial 82 finished with value: 0.9031792619048226 and parameters: {'max_depth': 6, 'learning_rate': 0.21548834594531363}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:31:17,022] Trial 83 finished with value: 0.906187388535438 and parameters: {'max_depth': 4, 'learning_rate': 0.10368906422444352}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:31:28,555] Trial 84 finished with value: 0.9037396007788528 and parameters: {'max_depth': 3, 'learning_rate': 0.10222693785106429}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:31:43,439] Trial 85 finished with value: 0.9060989190577158 and parameters: {'max_depth': 4, 'learning_rate': 0.12943211848833927}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:31:58,308] Trial 86 finished with value: 0.906511778359976 and parameters: {'max_depth': 4, 'learning_rate': 0.13656712723639322}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:32:09,786] Trial 87 finished with value: 0.9042114649564924 and parameters: {'max_depth': 3, 'learning_rate': 0.13835537953403587}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:32:24,775] Trial 88 finished with value: 0.9044473905219764 and parameters: {'max_depth': 4, 'learning_rate': 0.0804932522182743}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:32:40,265] Trial 89 finished with value: 0.9059514212206059 and parameters: {'max_depth': 4, 'learning_rate': 0.16213034697505338}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:32:47,620] Trial 90 finished with value: 0.9028843445106306 and parameters: {'max_depth': 2, 'learning_rate': 0.12781236826218179}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:33:02,258] Trial 91 finished with value: 0.9058924659225775 and parameters: {'max_depth': 4, 'learning_rate': 0.20670547782477475}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:33:13,568] Trial 92 finished with value: 0.9052731874065243 and parameters: {'max_depth': 3, 'learning_rate': 0.17640320754000538}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:33:32,262] Trial 93 finished with value: 0.9042703811145071 and parameters: {'max_depth': 5, 'learning_rate': 0.25172270658143076}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:33:46,994] Trial 94 finished with value: 0.9049192233876049 and parameters: {'max_depth': 4, 'learning_rate': 0.09582769913427222}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:34:05,047] Trial 95 finished with value: 0.9058630117575714 and parameters: {'max_depth': 5, 'learning_rate': 0.16125179678385376}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:34:16,358] Trial 96 finished with value: 0.9043294433952399 and parameters: {'max_depth': 3, 'learning_rate': 0.1119990259350638}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:34:35,143] Trial 97 finished with value: 0.9055680421766943 and parameters: {'max_depth': 5, 'learning_rate': 0.1343946536130686}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:34:49,579] Trial 98 finished with value: 0.9057155347951357 and parameters: {'max_depth': 4, 'learning_rate': 0.18711788031027438}. Best is trial 62 with value: 0.9067772024491482.
# [I 2025-04-15 07:35:07,612] Trial 99 finished with value: 0.9058039755701812 and parameters: {'max_depth': 5, 'learning_rate': 0.08824504327540365}. Best is trial 62 with value: 0.9067772024491482.
# Accuracy on test data: 0.9049809785012829

# %% [markdown]
# For Q3 and Q4 ,use the following data.

# %%
dr=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv')
dr
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0             1.10            Ideal     H     SI1     VG       EX    GIA
# 1             0.83            Ideal     H     VS1     ID       ID   AGSL
# 2             0.85            Ideal     H     SI1     EX       EX    GIA
# 3             0.91            Ideal     E     SI1     VG       VG    GIA
# 4             0.83            Ideal     G     SI1     EX       EX    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price
# 0      5169
# 1      3470
# 2      3183
# 3      4370
# 4      3171
# ...     ...
# 5995   6250
# 5996   5328
# 5997   6157
# 5998  11206
# 5999  30507
#
# [6000 rows x 8 columns]

# %%
def Encoder(df):
          from sklearn import preprocessing
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = preprocessing.LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
dr=Encoder(dr)
dr
# Out:
#       Carat Weight  Cut  Color  Clarity  Polish  Symmetry  Report  Price
# 0             1.10    2      4        2       3         0       1   5169
# 1             0.83    2      4        3       2         2       0   3470
# 2             0.85    2      4        2       0         0       1   3183
# 3             0.91    2      1        2       3         3       1   4370
# 4             0.83    2      3        2       0         0       1   3171
# ...            ...  ...    ...      ...     ...       ...     ...    ...
# 5995          1.03    2      0        2       0         0       1   6250
# 5996          1.00    4      0        2       3         3       1   5328
# 5997          1.02    2      0        2       0         0       1   6157
# 5998          1.27    3      3        3       0         0       1  11206
# 5999          2.19    2      1        3       0         0       1  30507
#
# [6000 rows x 8 columns]

# %%
y = dr['Price'] #Output
X = dr.drop('Price',axis=1)
X
# Out:
#       Carat Weight  Cut  Color  Clarity  Polish  Symmetry  Report
# 0             1.10    2      4        2       3         0       1
# 1             0.83    2      4        3       2         2       0
# 2             0.85    2      4        2       0         0       1
# 3             0.91    2      1        2       3         3       1
# 4             0.83    2      3        2       0         0       1
# ...            ...  ...    ...      ...     ...       ...     ...
# 5995          1.03    2      0        2       0         0       1
# 5996          1.00    4      0        2       3         3       1
# 5997          1.02    2      0        2       0         0       1
# 5998          1.27    3      3        3       0         0       1
# 5999          2.19    2      1        3       0         0       1
#
# [6000 rows x 7 columns]

# %%
from sklearn.model_selection import  train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

# %% [markdown]
# Q3)Using Linear Regression,Decison Tree Random Forest,XGBoost, Light GBM and Gradient Boosting Classifier with default parameters (no parameter specifications except random_state) calculate R2 statistics on test data. Which method gives the best accuracy on test data

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split


# Assuming 'dr' is your DataFrame after encoding
y = dr['Price']  # Output
X = dr.drop('Price', axis=1)  # Input features

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

# Define the models with default parameters
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(random_state=17),
    'Random Forest': RandomForestRegressor(random_state=17),
    'XGBoost': XGBRegressor(random_state=17),
    'LightGBM': LGBMRegressor(random_state=17),
    'Gradient Boosting': GradientBoostingRegressor(random_state=17)
}

# Train and evaluate the models
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    results[name] = r2

# Print the R-squared values for each model
for model_name, r2_value in results.items():
    print(f"{model_name}: R² = {r2_value:.4f}")

# Find the best model based on R-squared
best_model = max(results, key=results.get)
print(f"The best model is: {best_model} with R² = {results[best_model]:.4f}")
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000200 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 193
# [LightGBM] [Info] Number of data points in the train set: 4500, number of used features: 7
# [LightGBM] [Info] Start training from score 11827.946667
# Linear Regression: R² = 0.8234
# Decision Tree: R² = 0.9592
# Random Forest: R² = 0.9800
# XGBoost: R² = 0.9809
# LightGBM: R² = 0.9813
# Gradient Boosting: R² = 0.9739
# The best model is: LightGBM with R² = 0.9813

# %% [markdown]
# Q4) Using optuna hyperparmeter optimization technique (100 trial)  with Random Forest,XGBoost, Light GBM and Gradient Boosting Regressor
#
#
# a)find best methods with  parameters  using Cross validation (CV=3) technique for the range of   parameters below. What are the best parameters for the method with highest cross validation R2?
#
# For random forest
#
#
#   "max_depth"   : trial.suggest_int("max_depth", 2,  X_train.shape[1]),
#   "max_features": trial.suggest_int("max_features", 2, X_train.shape[1])
#
# For XGBoost, Light GBM and Gradient Boosting Classifier
#
#   "max_depth": trial.suggest_int("max_depth", 2, X_train.shape[1]),
#   "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3,log=True)
#
# where X_train.shape[1] is number of columnns in the train data.
#
#  b)Evaluate the performance of the  method with highest cross validation R2 on test data. What is the R2 value? Are there any improvement of the same method with default parameters?

# %%
#code for q4a
import optuna
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor

def objective(trial):
    model_name = trial.suggest_categorical('model', ['RandomForest', 'XGBoost', 'LightGBM', 'GradientBoosting'])

    if model_name == 'RandomForest':
        max_depth = trial.suggest_int("max_depth", 2, X_train.shape[1])
        max_features = trial.suggest_int("max_features", 2, X_train.shape[1])
        model = RandomForestRegressor(max_depth=max_depth, max_features=max_features, random_state=17)

    elif model_name == 'XGBoost':
        max_depth = trial.suggest_int("max_depth", 2, X_train.shape[1])
        learning_rate = trial.suggest_float("learning_rate", 0.001, 0.3, log=True)
        model = XGBRegressor(max_depth=max_depth, learning_rate=learning_rate, random_state=17)

    elif model_name == 'LightGBM':
        max_depth = trial.suggest_int("max_depth", 2, X_train.shape[1])
        learning_rate = trial.suggest_float("learning_rate", 0.001, 0.3, log=True)
        model = LGBMRegressor(max_depth=max_depth, learning_rate=learning_rate, random_state=17)

    elif model_name == 'GradientBoosting':
        max_depth = trial.suggest_int("max_depth", 2, X_train.shape[1])
        learning_rate = trial.suggest_float("learning_rate", 0.001, 0.3, log=True)
        model = GradientBoostingRegressor(max_depth=max_depth, learning_rate=learning_rate, random_state=17)

    score = cross_val_score(model, X_train, y_train, cv=3, scoring='r2').mean()
    return score

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

best_trial = study.best_trial
best_model_params = best_trial.params
best_model_name = best_trial.params['model']

print(f"Best model: {best_model_name}")
print(f"Best parameters: {best_model_params}")
# Out:
# [I 2025-04-15 09:19:53,275] A new study created in memory with name: no-name-ecaa4346-cd1e-4078-ac88-d09012112265
# [I 2025-04-15 09:19:54,869] Trial 0 finished with value: 0.9720609785033627 and parameters: {'model': 'RandomForest', 'max_depth': 7, 'max_features': 5}. Best is trial 0 with value: 0.9720609785033627.
# [I 2025-04-15 09:19:55,197] Trial 1 finished with value: 0.9839165608088175 and parameters: {'model': 'XGBoost', 'max_depth': 7, 'learning_rate': 0.12483957419524931}. Best is trial 1 with value: 0.9839165608088175.
# [I 2025-04-15 09:19:55,329] Trial 2 finished with value: 0.5554145703658301 and parameters: {'model': 'LightGBM', 'max_depth': 3, 'learning_rate': 0.00546265081716558}. Best is trial 1 with value: 0.9839165608088175.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000133 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 174
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11712.700333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000096 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 173
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11804.154333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000593 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 179
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11966.985333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-04-15 09:19:56,614] Trial 3 finished with value: 0.9252795977575513 and parameters: {'model': 'GradientBoosting', 'max_depth': 5, 'learning_rate': 0.01643412848924483}. Best is trial 1 with value: 0.9839165608088175.
# [I 2025-04-15 09:19:58,594] Trial 4 finished with value: 0.9822044804788685 and parameters: {'model': 'GradientBoosting', 'max_depth': 7, 'learning_rate': 0.29123989631928543}. Best is trial 1 with value: 0.9839165608088175.
# [I 2025-04-15 09:19:58,821] Trial 5 finished with value: 0.20128087202707926 and parameters: {'model': 'XGBoost', 'max_depth': 2, 'learning_rate': 0.0015617881042286035}. Best is trial 1 with value: 0.9839165608088175.
# [I 2025-04-15 09:19:59,371] Trial 6 finished with value: 0.7430594344013942 and parameters: {'model': 'RandomForest', 'max_depth': 2, 'max_features': 4}. Best is trial 1 with value: 0.9839165608088175.
# [I 2025-04-15 09:19:59,619] Trial 7 finished with value: 0.648668626944224 and parameters: {'model': 'XGBoost', 'max_depth': 5, 'learning_rate': 0.006264383449711413}. Best is trial 1 with value: 0.9839165608088175.
# [I 2025-04-15 09:19:59,828] Trial 8 finished with value: 0.3075079507042778 and parameters: {'model': 'LightGBM', 'max_depth': 7, 'learning_rate': 0.0021467956446172896}. Best is trial 1 with value: 0.9839165608088175.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000129 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 174
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11712.700333
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000135 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 173
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11804.154333
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 179
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11966.985333
# [I 2025-04-15 09:19:59,920] Trial 9 finished with value: 0.13573155237852294 and parameters: {'model': 'LightGBM', 'max_depth': 2, 'learning_rate': 0.0010009534316968059}. Best is trial 1 with value: 0.9839165608088175.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000366 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 174
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11712.700333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000093 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 173
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11804.154333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 179
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11966.985333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000164 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 179
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 7
# [LightGBM] [Info] Start training from score 11966.985333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-04-15 09:21:03,347] Trial 98 finished with value: 0.9858986207025926 and parameters: {'model': 'GradientBoosting', 'max_depth': 4, 'learning_rate': 0.09749467025680868}. Best is trial 63 with value: 0.9867299300034776.
# [I 2025-04-15 09:21:04,249] Trial 99 finished with value: 0.9863073943521293 and parameters: {'model': 'GradientBoosting', 'max_depth': 4, 'learning_rate': 0.1720881410757889}. Best is trial 63 with value: 0.9867299300034776.
# Best model: GradientBoosting
# Best parameters: {'model': 'GradientBoosting', 'max_depth': 4, 'learning_rate': 0.18740618829788747}

# %%
#code for q4b

from sklearn.metrics import r2_score

if best_model_name == 'RandomForest':
    model = RandomForestRegressor(max_depth=best_model_params['max_depth'],
                                  max_features=best_model_params['max_features'], random_state=17)

elif best_model_name == 'XGBoost':
    model = XGBRegressor(max_depth=best_model_params['max_depth'],
                         learning_rate=best_model_params['learning_rate'], random_state=17)

elif best_model_name == 'LightGBM':
    model = LGBMRegressor(max_depth=best_model_params['max_depth'],
                          learning_rate=best_model_params['learning_rate'], random_state=17)

elif best_model_name == 'GradientBoosting':
    model = GradientBoostingRegressor(max_depth=best_model_params['max_depth'],
                                      learning_rate=best_model_params['learning_rate'], random_state=17)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
r2_value = r2_score(y_test, y_pred)
print(f"R² of the optimized model on test data: {r2_value:.4f}")

default_rf = RandomForestRegressor(random_state=17)
default_rf.fit(X_train, y_train)
default_y_pred = default_rf.predict(X_test)
default_r2_value = r2_score(y_test, default_y_pred)
print(f"R² of the default model (Random Forest): {default_r2_value:.4f}")
# Out:
# R² of the optimized model on test data: 0.9847
# R² of the default model (Random Forest): 0.9800
